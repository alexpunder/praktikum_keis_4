# %% [markdown]
# # Импорты библиотек

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Добавьте необходимые библиотеки здесь

# %% [markdown]
# # Чтение данных

# %%
df_path = "/your/path/to/file.csv"

df = df.read_csv(df_path)

df.head()

# %% [markdown]
# # Чистка и подготовка данных

# %%
# Ваш код на основе кода чек-пойнта 1 здесь

# %% [markdown]
# # Гипотезы

# %%
# Укажите список + стратегию проверки

# %% [markdown]
# # Проверка гипотез

# %% [markdown]
# ## Гипотеза 1

# %% [markdown]
# ### Проверка

# %%
# Код проверки гипотезы 1

# %% [markdown]
# ### Визуализация

# %%
# Код визуализации гипотезы 1

# %% [markdown]
# ## Гипотеза 2

# %% [markdown]
# ### Проверка

# %%
# Код проверки гипотезы 2

# %% [markdown]
# ### Визуализация

# %%
# Код визуализации гипотезы 2

# %% [markdown]
# ...
#
# ## Гипотеза N

# %% [markdown]
# ### Проверка

# %%
# Код проверки гипотезы N

# %% [markdown]
# ### Визуализация

# %%
# Код визуализации гипотезы N
